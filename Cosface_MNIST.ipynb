# %% [markdown]
# <a href="https://colab.research.google.com/github/LegendTime1/keras_cosface/blob/master/Cosface_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/cvqluu/Angular-Penalty-Softmax-Losses-Pytorch
# Out:
# Cloning into 'Angular-Penalty-Softmax-Losses-Pytorch'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 91 (delta 0), reused 0 (delta 0), pack-reused 88
# Receiving objects: 100% (91/91), 9.57 MiB | 23.51 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# %cd Angular-Penalty-Softmax-Losses-Pytorch/
# Out:
# /content/Angular-Penalty-Softmax-Losses-Pytorch

# %%
# !python train_fMNIST.py --num-epochs 4 --seed 1234 --use-cuda
# Out:
# ...
# 100% 26421880/26421880 [00:02<00:00, 12473935.24it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 29515/29515 [00:00<00:00, 210227.68it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 4422102/4422102 [00:01<00:00, 3875863.82it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100% 5148/5148 [00:00<00:00, 43184553.98it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Training Baseline model....
#   0% 0/4 [00:00<?, ?it/s]
#   0% 0/118 [00:00<?, ?it/s]
#   1% 1/118 [00:08<15:42,  8.06s/it]
#   3% 3/118 [00:08<04:09,  2.17s/it]
#   3% 4/118 [00:08<02:46,  1.46s/it]
#   4% 5/118 [00:08<01:54,  1.01s/it]
#   5% 6/118 [00:08<01:20,  1.39it/s]
#   6% 7/118 [00:08<00:58,  1.91it/s]
#   7% 8/118 [00:08<00:45,  2.43it/s]
#   8% 9/118 [00:08<00:34,  3.14it/s]
# ...

# %%
# !git clone https://github.com/tchaye59/keras-arcface.git
# Out:
# Cloning into 'keras-arcface'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 43 (delta 2), reused 7 (delta 2), pack-reused 36
# Receiving objects: 100% (43/43), 452.44 KiB | 3.33 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# %cd keras-arcface/
# Out:
# /content/keras-arcface

# %%
# !python train.py --arch vgg8_arcface
# Out:
# Traceback (most recent call last):
#   File "/content/keras-arcface/train.py", line 15, in <module>
#     from sklearn.model_selection import KFold, StratifiedKFold
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/__init__.py", line 23, in <module>
#     from ._validation import cross_val_score
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 32, in <module>
#     from ..metrics import check_scoring
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/__init__.py", line 42, in <module>
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/__init__.py", line 22, in <module>
#     from ._unsupervised import silhouette_samples
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_unsupervised.py", line 16, in <module>
#     from ..pairwise import pairwise_distances_chunked
# ...

# %%
# !python train.py --arch vgg8_cosface
# Out:
# 2023-09-28 19:43:12.530496: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-28 19:43:13.451886: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Config -----
# name: mnist_vgg8_cosface_3d
# arch: vgg8_cosface
# num_features: 3
# scheduler: CosineAnnealing
# epochs: 100
# batch_size: 128
# optimizer: SGD
# lr: 0.1
# min_lr: 0.001
# momentum: 0.5
# ------------
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# ...

# %%
# !pip install tensorrt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tensorrt: filename=tensorrt-8.6.1.post1-py2.py3-none-any.whl size=17281 sha256=fdf210e1d06813dd6d714a3a3f3d7a95ac663af371c2a6b9264d3a6fa986f8e6
#   Stored in directory: /root/.cache/pip/wheels/f4/c8/0e/b79b08e45752491b9acfdbd69e8a609e8b2ed7640dda5a3e59
# Successfully built tensorrt
# ...

# %%
# %matplotlib inline

# %%
# !python test_cosface.py
# Out:
# 2023-09-28 19:56:57.148394: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-28 19:56:58.101523: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-28 19:57:00.015423: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...
